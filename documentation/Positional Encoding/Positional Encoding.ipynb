# %% [markdown]
# # Figure generator
# This notebook is soley used for figure and table generation

# %%
import sys
sys.path.append('/Users/leonmarkwart/Library/Mobile Documents/com~apple~CloudDocs/HHU/Semester 3/Implementing Transformers/implementingtransformers/')

# %%
from modelling.positional_encoding import PositionalEncoding
import matplotlib.pyplot as plt
import torch

d_model = 512
max_len = 100

pos_enc = PositionalEncoding(d_model, max_len)
pe = pos_enc.pe.squeeze(0)
plt.figure(figsize=(16, 8))
plt.imshow(pe, cmap='viridis', aspect='auto')
plt.xlabel('Position')
plt.ylabel('Depth')
plt.colorbar(label='Encoding Value')
plt.savefig('positional_encoding.pdf', bbox_inches='tight')
plt.show()
